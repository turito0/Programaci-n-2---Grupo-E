# %% [markdown]
# <a href="https://colab.research.google.com/github/turito0/Programaci-n-2---Grupo-E/blob/main/ActividadDeRetroalimentacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b54fb896-0915-4ec8-8fc2-faad3319a38b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b54fb896-0915-4ec8-8fc2-faad3319a38b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('doctores.txt',sep='|', header=None)
df.columns=["Nombre","Especialidad","Años Experiencia","Sexo","Hospital"]
display(df)
# Out:
#     Nombre      Especialidad  Años Experiencia       Sexo          Hospital
# 0  Natalia     Traumatología                 5   Femenino     Clinica Norte
# 1   Arturo  Medicina General                10  Masculino        Centro Sur
# 2    Tomas        Neurología                 7  Masculino      Clínica Vida
# 3  Ricardo       Cardiología                 3  Masculino  Hospital Central
# 4   Susana         Pediatría                15   Femenino      Clínica Vida
# 5    Mario       Cardiología                 6  Masculino  Hospital Central

# %%
print("Promedio de experiencia:",df["Años Experiencia"].mean())
print("Máximo de experiencia:",df["Años Experiencia"].max())
print("Mínimo de experiencia:",df["Años Experiencia"].min())
# Out:
# Promedio de experiencia: 7.666666666666667
# Máximo de experiencia: 15
# Mínimo de experiencia: 3

# %%
#Filtrar por especialidad
print("Doctores de cardiología")
print(df[df["Especialidad"]=="Cardiología"])
#Filtrar por sexo
print("Doctores Femeninos")
print(df[df["Sexo"]=="femenino"])
# Out:
# Doctores de cardiología
#     Nombre Especialidad  Años Experiencia       Sexo          Hospital
# 3  Ricardo  Cardiología                 3  Masculino  Hospital Central
# 5    Mario  Cardiología                 6  Masculino  Hospital Central
# Doctores Femeninos
# Empty DataFrame
# Columns: [Nombre, Especialidad, Años Experiencia, Sexo, Hospital]
# Index: []

# %%
df['Especialidad'].value_counts().plot(kind='bar')
plt.title('Cantidad de doctores por especialidad')
plt.xlabel('Especialidad')
plt.ylabel('Cantidad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-940164591.py in <cell line: 0>()
#       1 df['Especialidad'].value_counts().plot(kind='bar')
# ----> 2 plt.title('Cantidad de doctores por especialidad')
#       3 plt.xlabel('Especialidad')
#       4 plt.ylabel('Cantidad')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
#Gráfico de pastel por sexo
df['Sexo'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('Distribución por sexo')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-83707765.py in <cell line: 0>()
#       1 #Gráfico de pastel por sexo
#       2 df['Sexo'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# ----> 3 plt.title('Distribución por sexo')
#       4 plt.show()
#
# NameError: name 'plt' is not defined
